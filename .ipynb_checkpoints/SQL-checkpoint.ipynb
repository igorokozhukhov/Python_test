# %% [markdown]
# ![image.png](attachment:image.png)
#
# первая - особо не изменяется
#
#
# вторая - более динамическая(постоянное изменение структур)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
connection = sqlite3.connect("db.sqlite3")
cursor = connection.cursor()
